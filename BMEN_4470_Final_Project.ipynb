# %% [markdown]
# # Library

# %%
import sys
import os
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import scipy.io as sio
import glob as glob
import tensorflow
import seaborn as sns

from scipy import signal
from matplotlib import pyplot as plt

from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Flatten, Add
from keras.layers import Conv2D, BatchNormalization, Permute
from keras.layers import SeparableConv2D, DepthwiseConv2D, AveragePooling2D
from keras.layers import Conv1D, Activation, Add
from keras import optimizers
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score

from torch.nn import init
from torch.nn.functional import elu
from torch.autograd import Variable

# %% [markdown]
# # Pre-Processing

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
'''files description
	a01T -- Training dataset and label
  a0XE -- dataset for Evaluation  
  A0XE -- labels Evaluation dataset
'''
data_path = '/gdrive/My Drive/BCICIV_2a_mat/'

# %%
def get_data(subject, training, path):
  '''load datasets
	subject -- number of subject in [1, .. ,9]
	training -- if True, load training data

  return: data, label, artifact,
  data -- (25,) array, dtype = float64
  label -- (288, 1) array, 1 to 4, dtype = int64
  trigger -- (288, 1) array
  artifact -- (288, 1) array, 0 or 1, dtype = int64
  eventtyp -- (, 1) array, only 769 to 772 are meaningful
  eventpos -- (, 1) array, position of event
  eventdur -- (, 1) array, duration of event
  '''
  if training:
    a = sio.loadmat(path+'a0'+str(subject)+'T.mat') # load subject EEG .mat file (master structure)
    # load the a0xT structure in the .mat file
    #[0, 0] to reduce structure dimension make other fields more accessable in this case
    adata = a['a0'+str(subject)+'T'][0, 0]
    label = np.reshape(adata['Classlabel'],-1).astype(np.int) # load label for each triggered event in the EEG file 
  else:
    a = sio.loadmat(path+'a0'+str(subject)+'E.mat') # load subject EEG .mat file (master structure)
    adata = a['a0'+str(subject)+'E'][0, 0] # load the a0xT structure in the .mat file
    label = sio.loadmat(path+'A0'+str(subject)+'E.mat')
    label = np.reshape(label['classlabel'],-1).astype(np.int)

  event = adata['EVENT'] # load event field in the EEG file 
  artifact = np.reshape(adata['ArtifactSelection'],-1).astype(np.int) # load event artifact in the EEG file 
  trigger = adata['TRIG'] # load trigger in the EEG file 
  data = adata['data'] # load trial data in the EEG file 
  data=np.transpose(data) # transpose the data so that temporal information is on x axis
  

  eventTYP = np.reshape(event['TYP'][0,0],-1).astype(np.int) # load the type of event in the 'EVENT' field
  eventPOS = np.reshape(event['POS'][0,0],-1).astype(np.int) # load the position of event in the 'EVENT' field
  eventDUR = np.reshape(event['DUR'][0,0],-1).astype(np.int) # load the duration of event in the 'EVENT' field

  return data, label, artifact, trigger, eventTYP, eventPOS, eventDUR

# %%
def slice_events(typ, pos, dur, artifact, trigger, label):

  '''Remove invalid trials and corresponding label
	typ - type of event (e.g.: start trial, invalid trial, target movement.. etc): array, dtype = int64 
  pos - position of the event in the collected data: array, dtype = int64
  dur - during of the event/trials: array, dtype = int64
  artifact - rejected event index correspond to position of starting a trial - logical array 
  trigger - position where a trial begins in the collected data: array, dtype = int64
  label - label/class for each trials: array, dtype = int64

  return: valid_pos, valid_dur, y_label
  valid_pos -- position of the valid trial (remove invalid trials) in collect data: array, dtype = float64
  valid_dur -- duration of valid trial duration: : array, dtype = float64
  y_label -- valid trials' label: array, dtype = float64
  '''

  evt = np.where(typ == 768) # trial triggered indices 
  evtpos = pos[evt].astype(np.int) # event triggered posistion in time (start index for temporal information in EEG data)

  artEvent = np.where(artifact == 1) # indice of artifacts
  invalid_TRI = trigger[artEvent] # invalid triggered event
  invalid_evt = np.where(evtpos == invalid_TRI)[1] # find indices where there is invlid event
  valid_pos = np.delete(evtpos,invalid_evt) # remove invalid event from original event triggered posistion

  evtdur = dur[evt].astype(np.int) # triggered event duration (number index for temporal information in EEG data)
  valid_dur = np.delete(evtdur,invalid_evt) # remove invalid event from original event triggered duration

  y_label = np.delete(label,invalid_evt) # labels for triggered event
  
  return valid_pos, valid_dur, y_label

# %%
def Subject_data_label(subject, path):

  '''generate training and testing data for subjects
	subject - subject number: int (1 - 9)
  path - path of the data: str

  return: X_train, y_train_ohe, X_test, y_test_ohe
  X_train -- normalized training data : 3x1 matrix, dtype: float64
  y_train_ohe -- one hot encoded label for training data: 1x4 matrix, dtype: int64
  X_test -- normalized testing data: 3x1 matrix, dtype: float64
  y_test_ohe -- one hot encoded label for testing data: 1x4 matrix, dtype: int64
  '''
  
#Training dataset
  [data, label, artifact, trigger, eventTYP, eventPOS, eventDUR] = get_data(subject, True, data_path)
  [valid_pos, valid_dur, y_label] = slice_events(eventTYP, eventPOS, eventDUR, artifact, trigger, label)

  X_train = np.zeros((len(valid_pos), 22, max(valid_dur))) #initilized an array for EEG data
  Y_train = np.zeros(len(valid_pos)) #initilized an array for EEG label

  for i, event_trig in enumerate(valid_pos):
    X_train[i,:, :] = data[0:22, event_trig : event_trig + valid_dur[i]] # Extract valid channel and trials - training
    Y_train[i] = y_label[i] # valid trials label - training
  
  X_train = X_train[:,np.newaxis, :, :] # add extra dimension to EEG training data
  y_train_ohe = to_categorical(Y_train - 1) # convert training label to one hot encode

# Evaluation dataset
  [data, label, artifact, trigger, eventTYP, eventPOS, eventDUR] = get_data(subject, False, data_path)
  [valid_pos, valid_dur, y_label] = slice_events(eventTYP, eventPOS, eventDUR, artifact, trigger, label)

  X_test = np.zeros((len(valid_pos), 22, max(valid_dur))) #initilized an array for EEG data
  Y_test = np.zeros(len(valid_pos)) #initilized an array for EEG label

  for i, event_trig in enumerate(valid_pos):
    X_test[i,:, :] = data[0:22, event_trig : event_trig + valid_dur[i]] # Extract valid channel and trials - testing
    Y_test[i] = y_label[i] # valid trials label - testing

  X_test = X_test[:,np.newaxis, :, :] # add extra dimension to EEG testing data
  y_test_ohe = to_categorical(Y_test - 1) # convert testing label to one hot encode

  # normalize training and testing data 
  for j in range(22):
    scaler = StandardScaler()
    scaler.fit(X_train[:,0,j,:])
    X_train[:,0,j,:] = scaler.transform(X_train[:,0,j,:])
    X_test[:,0,j,:] = scaler.transform(X_test[:,0,j,:])

  return X_train, y_train_ohe, X_test, y_test_ohe, Y_train, Y_test

# %% [markdown]
# # EEGTCNet Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Reference:
#
# T. M. Ingolfsson, M. Hersche, X. Wang, N. Kobayashi, L. Cavigelli, and L. Benini, “EEG-TCNet: An accurate temporal convolutional network for embedded motor-imagery brain–machine interfaces,” 2020 IEEE International Conference on Systems, Man, and Cybernetics (SMC), 2020.

# %% [markdown]
# ## Model

# %%
# EEGNet

def EEGNet(input_layer, filter, kernel_size, D ,num_channs,dropout):

    block1 = Conv2D(filter, (kernel_size, 1), padding = 'same', use_bias = False)(input_layer)
    block1 = BatchNormalization()(block1)
    
    block2 = DepthwiseConv2D((1, num_channs), use_bias = False, depth_multiplier = D)(block1)
    block2 = BatchNormalization()(block2)
    block2 = Activation('elu')(block2)
    block2 = AveragePooling2D((10,1))(block2)
    block2 = Dropout(dropout)(block2)

    F2= filter*D # Filter size for Separable Convolution

    block3 = SeparableConv2D(F2, (16, 1), use_bias = False, padding = 'same')(block2)
    block3 = BatchNormalization()(block3)
    block3 = Activation('elu')(block3)
    block3 = AveragePooling2D((10,1))(block3)
    block3 = Dropout(dropout)(block3)

    return block3

# %%
# TCN Block
def res_block(input_layer,input_dimension,kernel_size,filters,dropout, dilationFactor):
  # first convolution layer for residual block
  res_conv1 = Conv1D(filters,kernel_size=kernel_size,dilation_rate = dilationFactor, padding = 'causal')(input_layer)
  res_block = BatchNormalization()(res_conv1)
  res_block = Activation('elu')(res_block)
  res_block = Dropout(dropout)(res_block)
  # second convolution layer for residual block
  res_conv2 = Conv1D(filters,kernel_size=kernel_size, dilation_rate = dilationFactor, padding = 'causal')(res_block)
  res_block = BatchNormalization()(res_conv2)
  res_block = Activation('elu')(res_block)
  res_block = Dropout(dropout)(res_block)
# Convolution for input layer coming into the residual block to ensure output features dimension matches with input dimension 
  if(input_dimension != filters):
    conv = Conv1D(filters,kernel_size=1,padding='same')(input_layer)
    added = Add()([res_block,conv]) # output of residual block if input is from EEGNet block
  else:
    added = Add()([res_block,input_layer]) # output of residual block
  res_out = Activation('elu')(added)

  return res_out

def TCN_block(input_layer,input_dimension,depth,kernel_size,filters,dropout):
  for i in range(depth):
    # set residual input to EEGnet output and EEGNet output dimension as filter size if it's the first loop.
    if i == 0:
      current_output = input_layer
      input_dimension = input_dimension
    else:
      input_dimension = filters
    dilationFactor = 2 ** i # dilation factor
    current_output = res_block(current_output,input_dimension,kernel_size,filters,dropout, dilationFactor)

  return current_output

# %%
def EEGTCNet(num_classes, num_channs, Samples, layers,ks_TCN, filter_TCN, dropout_TCN, filter_EEG, D, ks_EEG, dropout_EEG):
    input1 = Input(shape = (1,num_channs, Samples))
    input2 = Permute((3,2,1))(input1) # rearrange input dimension to match kernel in EEGnet

    F1 = filter_EEG
    F2= F1*D # EEGNet output dimension

    EEGNet_block = EEGNet(input_layer=input2,filter=F1,kernel_size=ks_EEG,D=D,num_channs=num_channs,dropout=dropout_EEG)
    EEGNet_block = tensorflow.squeeze(EEGNet_block, axis = 2) # reduce output dimension to match 1d convolution reqirement in TCN

    TCN = TCN_block(input_layer=EEGNet_block, input_dimension=F2, depth=layers, kernel_size=ks_TCN, filters=filter_TCN, dropout=dropout_TCN)
    TCN = TCN[:,-1,:] # reduce output dimension to obtain desired model output shape 

    main_output = Dense(num_classes, activation = 'softmax')(TCN)

    Model_EEGTCNet = Model(inputs= input1, outputs=main_output)
    Model_EEGTCNet.compile(optimizer = keras.optimizers.Adam(learning_rate=5e-4), loss = 'categorical_crossentropy',metrics = ['accuracy'])
    
    return Model_EEGTCNet

# %% [markdown]
# ## Training Model

# %%
# training parameter

f_e = 8 # EEGNet convolution filter
f_t = 12 # TCN convolution filter
k_e = 32 # kernel size of first convolution in EEGnet block
k_t = 4 # kernel size for TCN block
L = 2 # number of residual blocks
D = 2 # depth multiplier for depthwiese convolution - increase number of filters
channels = 22 # number of channels for EEG data
dropout_e = 0.2 # dropout rate in EEGnet block
dropout_t = 0.3 # dropout rate in TCN block
classes = 4 # 4 different labels/classes in dataset

# %%
accuracy = np.zeros(9)

for subject in range(1, 10):

  [X_train, y_train_ohe, X_test, y_test_ohe, Y_train, Y_test] = Subject_data_label(subject, data_path) # Subject EEG data and labels 
  samples = X_train.shape[3] # number of data points for each trials

  # Model training 
  model = EEGTCNet(num_classes = classes, num_channs = channels, Samples = samples, layers = L ,ks_TCN = k_t, filter_TCN = f_t, dropout_TCN = dropout_t, 
                  filter_EEG = f_e, D = D, ks_EEG = k_e, dropout_EEG = dropout_e)
  history = model.fit(X_train, y_train_ohe, epochs=600, batch_size=32)

  # Model Testing / Evaluation
  scores = model.evaluate(X_test,y_test_ohe, verbose=1)
  accuracy[subject-1] = scores[1]*100

# calculate average accuracy among the subjects
accuracy_avg = np.average(accuracy)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 504/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3503 - accuracy: 0.8588
# Epoch 505/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.3678 - accuracy: 0.8550
# Epoch 506/600
# 9/9 [==============================] - 0s 46ms/step - loss: 0.4202 - accuracy: 0.8588
# Epoch 507/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2543 - accuracy: 0.9198
# Epoch 508/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.3381 - accuracy: 0.8855
# Epoch 509/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2688 - accuracy: 0.9084
# Epoch 510/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2937 - accuracy: 0.8740
# Epoch 511/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2883 - accuracy: 0.9122
# Epoch 512/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.3207 - accuracy: 0.8893
# Epoch 513/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2794 - accuracy: 0.8817
# Epoch 514/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2673 - accuracy: 0.9237
# Epoch 515/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3469 - accuracy: 0.8817
# Epoch 516/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2689 - accuracy: 0.9008
# Epoch 517/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3196 - accuracy: 0.8702
# Epoch 518/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.3549 - accuracy: 0.8817
# Epoch 519/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2701 - accuracy: 0.9122
# Epoch 520/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2941 - accuracy: 0.8817
# Epoch 521/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3462 - accuracy: 0.8740
# Epoch 522/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3187 - accuracy: 0.8817
# Epoch 523/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4416 - accuracy: 0.8168
# Epoch 524/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2348 - accuracy: 0.9389
# Epoch 525/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2854 - accuracy: 0.8855
# Epoch 526/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2705 - accuracy: 0.8969
# Epoch 527/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.3273 - accuracy: 0.8779
# Epoch 528/600
# 9/9 [==============================] - 0s 46ms/step - loss: 0.2761 - accuracy: 0.9046
# Epoch 529/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2556 - accuracy: 0.9237
# Epoch 530/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3595 - accuracy: 0.8969
# Epoch 531/600
# 9/9 [==============================] - 0s 52ms/step - loss: 0.3019 - accuracy: 0.8969
# Epoch 532/600
# 9/9 [==============================] - 0s 54ms/step - loss: 0.4025 - accuracy: 0.8702
# Epoch 533/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2635 - accuracy: 0.8969
# Epoch 534/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3312 - accuracy: 0.8893
# Epoch 535/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3125 - accuracy: 0.9084
# Epoch 536/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3345 - accuracy: 0.8969
# Epoch 537/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3190 - accuracy: 0.8740
# Epoch 538/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2337 - accuracy: 0.9084
# Epoch 539/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2429 - accuracy: 0.9122
# Epoch 540/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2625 - accuracy: 0.9046
# Epoch 541/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2737 - accuracy: 0.9008
# Epoch 542/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2446 - accuracy: 0.9008
# Epoch 543/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3214 - accuracy: 0.8855
# Epoch 544/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2994 - accuracy: 0.9008
# Epoch 545/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2603 - accuracy: 0.9084
# Epoch 546/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3127 - accuracy: 0.8779
# Epoch 547/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2759 - accuracy: 0.9084
# Epoch 548/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.3053 - accuracy: 0.8855
# Epoch 549/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2279 - accuracy: 0.9466
# Epoch 550/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2502 - accuracy: 0.9160
# Epoch 551/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2864 - accuracy: 0.9008
# Epoch 552/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2893 - accuracy: 0.9046
# Epoch 553/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2566 - accuracy: 0.9160
# Epoch 554/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2802 - accuracy: 0.9008
# Epoch 555/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2895 - accuracy: 0.8969
# Epoch 556/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2670 - accuracy: 0.8969
# Epoch 557/600
# 9/9 [==============================] - 0s 52ms/step - loss: 0.3008 - accuracy: 0.9008
# Epoch 558/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2425 - accuracy: 0.9084
# Epoch 559/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2889 - accuracy: 0.9122
# Epoch 560/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2511 - accuracy: 0.9198
# Epoch 561/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.3049 - accuracy: 0.8893
# Epoch 562/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2724 - accuracy: 0.8893
# Epoch 563/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2683 - accuracy: 0.9160
# Epoch 564/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2391 - accuracy: 0.9237
# Epoch 565/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2197 - accuracy: 0.9275
# Epoch 566/600
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2609 - accuracy: 0.9084
# Epoch 567/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2542 - accuracy: 0.8893
# Epoch 568/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2263 - accuracy: 0.9237
# Epoch 569/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2238 - accuracy: 0.9237
# Epoch 570/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2498 - accuracy: 0.9160
# Epoch 571/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2560 - accuracy: 0.9084
# Epoch 572/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3174 - accuracy: 0.8931
# Epoch 573/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.1963 - accuracy: 0.9427
# Epoch 574/600
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2214 - accuracy: 0.9084
# Epoch 575/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2548 - accuracy: 0.9046
# Epoch 576/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2279 - accuracy: 0.9084
# Epoch 577/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2044 - accuracy: 0.9275
# Epoch 578/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2758 - accuracy: 0.8893
# Epoch 579/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2649 - accuracy: 0.9046
# Epoch 580/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2741 - accuracy: 0.8969
# Epoch 581/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2847 - accuracy: 0.8893
# Epoch 582/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3280 - accuracy: 0.8969
# Epoch 583/600
# 9/9 [==============================] - 0s 52ms/step - loss: 0.2721 - accuracy: 0.8931
# Epoch 584/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3107 - accuracy: 0.8893
# Epoch 585/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2570 - accuracy: 0.9046
# Epoch 586/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2810 - accuracy: 0.9122
# Epoch 587/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2547 - accuracy: 0.9008
# Epoch 588/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2409 - accuracy: 0.8969
# Epoch 589/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2945 - accuracy: 0.9008
# Epoch 590/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2881 - accuracy: 0.8969
# Epoch 591/600
# 9/9 [==============================] - 0s 52ms/step - loss: 0.2514 - accuracy: 0.9198
# Epoch 592/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2421 - accuracy: 0.9351
# Epoch 593/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2490 - accuracy: 0.9008
# Epoch 594/600
# 9/9 [==============================] - 0s 50ms/step - loss: 0.2986 - accuracy: 0.9046
# Epoch 595/600
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2098 - accuracy: 0.9389
# Epoch 596/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2675 - accuracy: 0.8969
# Epoch 597/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2137 - accuracy: 0.9237
# Epoch 598/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2689 - accuracy: 0.8969
# Epoch 599/600
# 9/9 [==============================] - 0s 52ms/step - loss: 0.2596 - accuracy: 0.8893
# Epoch 600/600
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2770 - accuracy: 0.9084
# 9/9 [==============================] - 1s 34ms/step - loss: 1.2504 - accuracy: 0.5797
# Epoch 1/600
# 7/7 [==============================] - 3s 79ms/step - loss: 2.3553 - accuracy: 0.2694
# Epoch 2/600
# 7/7 [==============================] - 0s 50ms/step - loss: 2.3588 - accuracy: 0.2374
# Epoch 3/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.9030 - accuracy: 0.3151
# Epoch 4/600
# 7/7 [==============================] - 0s 54ms/step - loss: 2.1652 - accuracy: 0.2740
# Epoch 5/600
# 7/7 [==============================] - 0s 60ms/step - loss: 2.0835 - accuracy: 0.3288
# Epoch 6/600
# 7/7 [==============================] - 0s 53ms/step - loss: 2.0541 - accuracy: 0.2603
# Epoch 7/600
# 7/7 [==============================] - 0s 52ms/step - loss: 2.0371 - accuracy: 0.2511
# Epoch 8/600
# 7/7 [==============================] - 0s 52ms/step - loss: 2.0199 - accuracy: 0.2831
# Epoch 9/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.8827 - accuracy: 0.2694
# Epoch 10/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.8810 - accuracy: 0.2603
# Epoch 11/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.9031 - accuracy: 0.2877
# Epoch 12/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.6913 - accuracy: 0.3288
# Epoch 13/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.9654 - accuracy: 0.2694
# Epoch 14/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.7552 - accuracy: 0.3242
# Epoch 15/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.7777 - accuracy: 0.3059
# Epoch 16/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.8072 - accuracy: 0.3288
# Epoch 17/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.5351 - accuracy: 0.3699
# Epoch 18/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.6966 - accuracy: 0.3379
# Epoch 19/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.7247 - accuracy: 0.3014
# Epoch 20/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.7882 - accuracy: 0.2877
# Epoch 21/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.6449 - accuracy: 0.3607
# Epoch 22/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.7076 - accuracy: 0.3333
# Epoch 23/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.7196 - accuracy: 0.3196
# Epoch 24/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.5889 - accuracy: 0.3607
# Epoch 25/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.5315 - accuracy: 0.3881
# Epoch 26/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.6212 - accuracy: 0.3425
# Epoch 27/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.6337 - accuracy: 0.2968
# Epoch 28/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.5270 - accuracy: 0.3744
# Epoch 29/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.5653 - accuracy: 0.3333
# Epoch 30/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.6052 - accuracy: 0.3242
# Epoch 31/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.5954 - accuracy: 0.2922
# Epoch 32/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.5332 - accuracy: 0.3562
# Epoch 33/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.5557 - accuracy: 0.3607
# Epoch 34/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.4494 - accuracy: 0.3927
# Epoch 35/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.5084 - accuracy: 0.3699
# Epoch 36/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.3800 - accuracy: 0.3927
# Epoch 37/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.3923 - accuracy: 0.3881
# Epoch 38/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.3545 - accuracy: 0.3927
# Epoch 39/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.5044 - accuracy: 0.3562
# Epoch 40/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.5113 - accuracy: 0.3699
# Epoch 41/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.3815 - accuracy: 0.4018
# Epoch 42/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.4113 - accuracy: 0.3699
# Epoch 43/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.4605 - accuracy: 0.3973
# Epoch 44/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.4224 - accuracy: 0.3790
# Epoch 45/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.3723 - accuracy: 0.4338
# Epoch 46/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.3207 - accuracy: 0.4292
# Epoch 47/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.3684 - accuracy: 0.4247
# Epoch 48/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.4521 - accuracy: 0.3881
# Epoch 49/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.3859 - accuracy: 0.3790
# Epoch 50/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.3335 - accuracy: 0.4201
# Epoch 51/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.4079 - accuracy: 0.3881
# Epoch 52/600
# 7/7 [==============================] - 0s 49ms/step - loss: 1.3594 - accuracy: 0.4658
# Epoch 53/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2640 - accuracy: 0.4292
# Epoch 54/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.3485 - accuracy: 0.3699
# Epoch 55/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.4574 - accuracy: 0.3653
# Epoch 56/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.3403 - accuracy: 0.3881
# Epoch 57/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.3214 - accuracy: 0.4384
# Epoch 58/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.3063 - accuracy: 0.4338
# Epoch 59/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.3870 - accuracy: 0.4018
# Epoch 60/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2944 - accuracy: 0.4795
# Epoch 61/600
# 7/7 [==============================] - 0s 49ms/step - loss: 1.2796 - accuracy: 0.4475
# Epoch 62/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2475 - accuracy: 0.4018
# Epoch 63/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2949 - accuracy: 0.3927
# Epoch 64/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.2390 - accuracy: 0.4566
# Epoch 65/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.4156 - accuracy: 0.3790
# Epoch 66/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.2509 - accuracy: 0.4749
# Epoch 67/600
# 7/7 [==============================] - 0s 49ms/step - loss: 1.2534 - accuracy: 0.4795
# Epoch 68/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2650 - accuracy: 0.4658
# Epoch 69/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.2139 - accuracy: 0.4429
# Epoch 70/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1640 - accuracy: 0.4658
# Epoch 71/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2827 - accuracy: 0.4566
# Epoch 72/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2337 - accuracy: 0.4703
# Epoch 73/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.1521 - accuracy: 0.4977
# Epoch 74/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.2476 - accuracy: 0.4886
# Epoch 75/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.2197 - accuracy: 0.4475
# Epoch 76/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.3303 - accuracy: 0.4429
# Epoch 77/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.2830 - accuracy: 0.4475
# Epoch 78/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.2521 - accuracy: 0.4932
# Epoch 79/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2072 - accuracy: 0.4749
# Epoch 80/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2037 - accuracy: 0.5068
# Epoch 81/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.3079 - accuracy: 0.4384
# Epoch 82/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.2197 - accuracy: 0.4566
# Epoch 83/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1502 - accuracy: 0.4977
# Epoch 84/600
# 7/7 [==============================] - 0s 49ms/step - loss: 1.2103 - accuracy: 0.4612
# Epoch 85/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.1526 - accuracy: 0.5205
# Epoch 86/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2060 - accuracy: 0.4292
# Epoch 87/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.2805 - accuracy: 0.4658
# Epoch 88/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.1807 - accuracy: 0.4932
# Epoch 89/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.2094 - accuracy: 0.4977
# Epoch 90/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1827 - accuracy: 0.5662
# Epoch 91/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1668 - accuracy: 0.4932
# Epoch 92/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1430 - accuracy: 0.5114
# Epoch 93/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.1095 - accuracy: 0.5114
# Epoch 94/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.2765 - accuracy: 0.4247
# Epoch 95/600
# 7/7 [==============================] - 0s 50ms/step - loss: 1.2156 - accuracy: 0.4886
# Epoch 96/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.1893 - accuracy: 0.4658
# Epoch 97/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1808 - accuracy: 0.4749
# Epoch 98/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.2036 - accuracy: 0.4475
# Epoch 99/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.1192 - accuracy: 0.5068
# Epoch 100/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1449 - accuracy: 0.4749
# Epoch 101/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.1502 - accuracy: 0.5023
# Epoch 102/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.2492 - accuracy: 0.3927
# Epoch 103/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1674 - accuracy: 0.5114
# Epoch 104/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1941 - accuracy: 0.4658
# Epoch 105/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.1573 - accuracy: 0.5160
# Epoch 106/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0979 - accuracy: 0.5434
# Epoch 107/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0902 - accuracy: 0.5342
# Epoch 108/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.1518 - accuracy: 0.4977
# Epoch 109/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0789 - accuracy: 0.5434
# Epoch 110/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1101 - accuracy: 0.5114
# Epoch 111/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0892 - accuracy: 0.5023
# Epoch 112/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1512 - accuracy: 0.5023
# Epoch 113/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.0474 - accuracy: 0.5799
# Epoch 114/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0995 - accuracy: 0.5068
# Epoch 115/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0443 - accuracy: 0.5936
# Epoch 116/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0460 - accuracy: 0.5023
# Epoch 117/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.1168 - accuracy: 0.4977
# Epoch 118/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0813 - accuracy: 0.5388
# Epoch 119/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0484 - accuracy: 0.5890
# Epoch 120/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.1198 - accuracy: 0.4932
# Epoch 121/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0446 - accuracy: 0.5525
# Epoch 122/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0501 - accuracy: 0.5342
# Epoch 123/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0600 - accuracy: 0.5297
# Epoch 124/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1889 - accuracy: 0.4429
# Epoch 125/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0449 - accuracy: 0.5434
# Epoch 126/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0806 - accuracy: 0.5388
# Epoch 127/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.0341 - accuracy: 0.5708
# Epoch 128/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0699 - accuracy: 0.5205
# Epoch 129/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0505 - accuracy: 0.5662
# Epoch 130/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9959 - accuracy: 0.5616
# Epoch 131/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1545 - accuracy: 0.4886
# Epoch 132/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0264 - accuracy: 0.5890
# Epoch 133/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0417 - accuracy: 0.5799
# Epoch 134/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.0083 - accuracy: 0.5799
# Epoch 135/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.0601 - accuracy: 0.5023
# Epoch 136/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0248 - accuracy: 0.5753
# Epoch 137/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.0105 - accuracy: 0.6119
# Epoch 138/600
# 7/7 [==============================] - 0s 57ms/step - loss: 1.0355 - accuracy: 0.5479
# Epoch 139/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0388 - accuracy: 0.5799
# Epoch 140/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.0529 - accuracy: 0.5708
# Epoch 141/600
# 7/7 [==============================] - 0s 56ms/step - loss: 1.0363 - accuracy: 0.5525
# Epoch 142/600
# 7/7 [==============================] - 0s 51ms/step - loss: 1.0061 - accuracy: 0.5571
# Epoch 143/600
# 7/7 [==============================] - 0s 52ms/step - loss: 1.0203 - accuracy: 0.5936
# Epoch 144/600
# 7/7 [==============================] - 0s 53ms/step - loss: 1.0087 - accuracy: 0.6164
# Epoch 145/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.9683 - accuracy: 0.5982
# Epoch 146/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0110 - accuracy: 0.5525
# Epoch 147/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.9402 - accuracy: 0.6393
# Epoch 148/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.9741 - accuracy: 0.6027
# Epoch 149/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.9565 - accuracy: 0.6073
# Epoch 150/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9505 - accuracy: 0.6073
# Epoch 151/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.9902 - accuracy: 0.6210
# Epoch 152/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9116 - accuracy: 0.6119
# Epoch 153/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9707 - accuracy: 0.5890
# Epoch 154/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.9525 - accuracy: 0.5753
# Epoch 155/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9537 - accuracy: 0.5936
# Epoch 156/600
# 7/7 [==============================] - 0s 54ms/step - loss: 1.0237 - accuracy: 0.5845
# Epoch 157/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9521 - accuracy: 0.5708
# Epoch 158/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9478 - accuracy: 0.5708
# Epoch 159/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9645 - accuracy: 0.6027
# Epoch 160/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.9204 - accuracy: 0.6484
# Epoch 161/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.9476 - accuracy: 0.6164
# Epoch 162/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9577 - accuracy: 0.6119
# Epoch 163/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.8932 - accuracy: 0.6210
# Epoch 164/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.9266 - accuracy: 0.5936
# Epoch 165/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.9270 - accuracy: 0.6119
# Epoch 166/600
# 7/7 [==============================] - 0s 55ms/step - loss: 1.0207 - accuracy: 0.5525
# Epoch 167/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9971 - accuracy: 0.5799
# Epoch 168/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8939 - accuracy: 0.6164
# Epoch 169/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9892 - accuracy: 0.5799
# Epoch 170/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8954 - accuracy: 0.6164
# Epoch 171/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8836 - accuracy: 0.6256
# Epoch 172/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.9985 - accuracy: 0.6484
# Epoch 173/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8753 - accuracy: 0.6575
# Epoch 174/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.9081 - accuracy: 0.6256
# Epoch 175/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8732 - accuracy: 0.6164
# Epoch 176/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.9235 - accuracy: 0.6393
# Epoch 177/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.8291 - accuracy: 0.6667
# Epoch 178/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.9636 - accuracy: 0.5936
# Epoch 179/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8952 - accuracy: 0.6164
# Epoch 180/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8240 - accuracy: 0.6986
# Epoch 181/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.9581 - accuracy: 0.6119
# Epoch 182/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7902 - accuracy: 0.7032
# Epoch 183/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.8775 - accuracy: 0.6438
# Epoch 184/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.9327 - accuracy: 0.6027
# Epoch 185/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.9261 - accuracy: 0.5845
# Epoch 186/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.8568 - accuracy: 0.6667
# Epoch 187/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8276 - accuracy: 0.7032
# Epoch 188/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8292 - accuracy: 0.6484
# Epoch 189/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8194 - accuracy: 0.6712
# Epoch 190/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9372 - accuracy: 0.6347
# Epoch 191/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8458 - accuracy: 0.6575
# Epoch 192/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.8827 - accuracy: 0.6164
# Epoch 193/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8885 - accuracy: 0.6667
# Epoch 194/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8068 - accuracy: 0.6849
# Epoch 195/600
# 7/7 [==============================] - 0s 49ms/step - loss: 0.8845 - accuracy: 0.6758
# Epoch 196/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9098 - accuracy: 0.6712
# Epoch 197/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8606 - accuracy: 0.6164
# Epoch 198/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8873 - accuracy: 0.6347
# Epoch 199/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8809 - accuracy: 0.6256
# Epoch 200/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8616 - accuracy: 0.5982
# Epoch 201/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7489 - accuracy: 0.7397
# Epoch 202/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8522 - accuracy: 0.6621
# Epoch 203/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7837 - accuracy: 0.6804
# Epoch 204/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7964 - accuracy: 0.6758
# Epoch 205/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8169 - accuracy: 0.6986
# Epoch 206/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.8775 - accuracy: 0.6347
# Epoch 207/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8469 - accuracy: 0.6575
# Epoch 208/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.7657 - accuracy: 0.7260
# Epoch 209/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.8086 - accuracy: 0.6804
# Epoch 210/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.8109 - accuracy: 0.6393
# Epoch 211/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8055 - accuracy: 0.6895
# Epoch 212/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7491 - accuracy: 0.7352
# Epoch 213/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8122 - accuracy: 0.6530
# Epoch 214/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.8694 - accuracy: 0.6575
# Epoch 215/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8428 - accuracy: 0.6484
# Epoch 216/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8095 - accuracy: 0.6667
# Epoch 217/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.7962 - accuracy: 0.6621
# Epoch 218/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8466 - accuracy: 0.6393
# Epoch 219/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.7777 - accuracy: 0.7078
# Epoch 220/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8548 - accuracy: 0.6210
# Epoch 221/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.7837 - accuracy: 0.6941
# Epoch 222/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7715 - accuracy: 0.7032
# Epoch 223/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8460 - accuracy: 0.6530
# Epoch 224/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.7497 - accuracy: 0.7032
# Epoch 225/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7556 - accuracy: 0.7215
# Epoch 226/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.8202 - accuracy: 0.6575
# Epoch 227/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7628 - accuracy: 0.6986
# Epoch 228/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.7302 - accuracy: 0.7078
# Epoch 229/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7033 - accuracy: 0.7626
# Epoch 230/600
# 7/7 [==============================] - 0s 49ms/step - loss: 0.7665 - accuracy: 0.6941
# Epoch 231/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6863 - accuracy: 0.7260
# Epoch 232/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7300 - accuracy: 0.7078
# Epoch 233/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7284 - accuracy: 0.6986
# Epoch 234/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7456 - accuracy: 0.7032
# Epoch 235/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7388 - accuracy: 0.7169
# Epoch 236/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.7019 - accuracy: 0.7489
# Epoch 237/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6776 - accuracy: 0.7626
# Epoch 238/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7571 - accuracy: 0.7078
# Epoch 239/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.7838 - accuracy: 0.7123
# Epoch 240/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7343 - accuracy: 0.6667
# Epoch 241/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7382 - accuracy: 0.6941
# Epoch 242/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.7170 - accuracy: 0.7169
# Epoch 243/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6635 - accuracy: 0.7763
# Epoch 244/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.7503 - accuracy: 0.7123
# Epoch 245/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6946 - accuracy: 0.7489
# Epoch 246/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6589 - accuracy: 0.7352
# Epoch 247/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.7607 - accuracy: 0.6758
# Epoch 248/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6236 - accuracy: 0.7945
# Epoch 249/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.6822 - accuracy: 0.7260
# Epoch 250/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6380 - accuracy: 0.7534
# Epoch 251/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6771 - accuracy: 0.7671
# Epoch 252/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7245 - accuracy: 0.6895
# Epoch 253/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7023 - accuracy: 0.7169
# Epoch 254/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6565 - accuracy: 0.7489
# Epoch 255/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6854 - accuracy: 0.7215
# Epoch 256/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.7125 - accuracy: 0.7534
# Epoch 257/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.6265 - accuracy: 0.7671
# Epoch 258/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.6683 - accuracy: 0.7260
# Epoch 259/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6837 - accuracy: 0.7260
# Epoch 260/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6017 - accuracy: 0.7945
# Epoch 261/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6558 - accuracy: 0.7443
# Epoch 262/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6933 - accuracy: 0.7123
# Epoch 263/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6871 - accuracy: 0.7123
# Epoch 264/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5766 - accuracy: 0.7671
# Epoch 265/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6322 - accuracy: 0.7763
# Epoch 266/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6328 - accuracy: 0.7626
# Epoch 267/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5767 - accuracy: 0.7580
# Epoch 268/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6471 - accuracy: 0.7260
# Epoch 269/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6717 - accuracy: 0.7123
# Epoch 270/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6518 - accuracy: 0.7123
# Epoch 271/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6363 - accuracy: 0.7443
# Epoch 272/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6400 - accuracy: 0.7717
# Epoch 273/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6080 - accuracy: 0.7306
# Epoch 274/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5836 - accuracy: 0.8037
# Epoch 275/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.6561 - accuracy: 0.7534
# Epoch 276/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6243 - accuracy: 0.7808
# Epoch 277/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6100 - accuracy: 0.7717
# Epoch 278/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6442 - accuracy: 0.7580
# Epoch 279/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5919 - accuracy: 0.7671
# Epoch 280/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6170 - accuracy: 0.7763
# Epoch 281/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5900 - accuracy: 0.7854
# Epoch 282/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5595 - accuracy: 0.7671
# Epoch 283/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.5467 - accuracy: 0.8082
# Epoch 284/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6124 - accuracy: 0.7763
# Epoch 285/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7013 - accuracy: 0.7123
# Epoch 286/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6414 - accuracy: 0.7306
# Epoch 287/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6612 - accuracy: 0.7580
# Epoch 288/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5652 - accuracy: 0.7808
# Epoch 289/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6049 - accuracy: 0.7945
# Epoch 290/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5865 - accuracy: 0.7626
# Epoch 291/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6313 - accuracy: 0.7717
# Epoch 292/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5387 - accuracy: 0.8037
# Epoch 293/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6332 - accuracy: 0.7397
# Epoch 294/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5837 - accuracy: 0.7671
# Epoch 295/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.6061 - accuracy: 0.7808
# Epoch 296/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5074 - accuracy: 0.8174
# Epoch 297/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6738 - accuracy: 0.7808
# Epoch 298/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5836 - accuracy: 0.7580
# Epoch 299/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5976 - accuracy: 0.7671
# Epoch 300/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5049 - accuracy: 0.8402
# Epoch 301/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5577 - accuracy: 0.7671
# Epoch 302/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5413 - accuracy: 0.7900
# Epoch 303/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5456 - accuracy: 0.7991
# Epoch 304/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5875 - accuracy: 0.7808
# Epoch 305/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5393 - accuracy: 0.8037
# Epoch 306/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5490 - accuracy: 0.7763
# Epoch 307/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5576 - accuracy: 0.7534
# Epoch 308/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5829 - accuracy: 0.7489
# Epoch 309/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5424 - accuracy: 0.7945
# Epoch 310/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5402 - accuracy: 0.8037
# Epoch 311/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5215 - accuracy: 0.8174
# Epoch 312/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4829 - accuracy: 0.8174
# Epoch 313/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5317 - accuracy: 0.7808
# Epoch 314/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5543 - accuracy: 0.7900
# Epoch 315/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4912 - accuracy: 0.8082
# Epoch 316/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5096 - accuracy: 0.8265
# Epoch 317/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5539 - accuracy: 0.8082
# Epoch 318/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5385 - accuracy: 0.8219
# Epoch 319/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5310 - accuracy: 0.7991
# Epoch 320/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4156 - accuracy: 0.8311
# Epoch 321/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5921 - accuracy: 0.7626
# Epoch 322/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5605 - accuracy: 0.7854
# Epoch 323/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5664 - accuracy: 0.7945
# Epoch 324/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5491 - accuracy: 0.7991
# Epoch 325/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5328 - accuracy: 0.7991
# Epoch 326/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4694 - accuracy: 0.8265
# Epoch 327/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5182 - accuracy: 0.7854
# Epoch 328/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5133 - accuracy: 0.8311
# Epoch 329/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5645 - accuracy: 0.7900
# Epoch 330/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5180 - accuracy: 0.8128
# Epoch 331/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5126 - accuracy: 0.8265
# Epoch 332/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4290 - accuracy: 0.8128
# Epoch 333/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4882 - accuracy: 0.8219
# Epoch 334/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5030 - accuracy: 0.8037
# Epoch 335/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5885 - accuracy: 0.8128
# Epoch 336/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6141 - accuracy: 0.7534
# Epoch 337/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4028 - accuracy: 0.8630
# Epoch 338/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5361 - accuracy: 0.8082
# Epoch 339/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5135 - accuracy: 0.8037
# Epoch 340/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5578 - accuracy: 0.7671
# Epoch 341/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4857 - accuracy: 0.7991
# Epoch 342/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5149 - accuracy: 0.8037
# Epoch 343/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4731 - accuracy: 0.8311
# Epoch 344/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5263 - accuracy: 0.7945
# Epoch 345/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4554 - accuracy: 0.8265
# Epoch 346/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4362 - accuracy: 0.8584
# Epoch 347/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4671 - accuracy: 0.8037
# Epoch 348/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5256 - accuracy: 0.8219
# Epoch 349/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4837 - accuracy: 0.7991
# Epoch 350/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4670 - accuracy: 0.8447
# Epoch 351/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5362 - accuracy: 0.7991
# Epoch 352/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5269 - accuracy: 0.8265
# Epoch 353/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4311 - accuracy: 0.8265
# Epoch 354/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5188 - accuracy: 0.7900
# Epoch 355/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4219 - accuracy: 0.8676
# Epoch 356/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.3984 - accuracy: 0.8676
# Epoch 357/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3927 - accuracy: 0.8721
# Epoch 358/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4858 - accuracy: 0.8265
# Epoch 359/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4350 - accuracy: 0.8128
# Epoch 360/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4066 - accuracy: 0.8493
# Epoch 361/600
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4213 - accuracy: 0.8356
# Epoch 362/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4651 - accuracy: 0.7991
# Epoch 363/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.4960 - accuracy: 0.8082
# Epoch 364/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4761 - accuracy: 0.8037
# Epoch 365/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4118 - accuracy: 0.8447
# Epoch 366/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4311 - accuracy: 0.8630
# Epoch 367/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.4207 - accuracy: 0.8584
# Epoch 368/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4759 - accuracy: 0.8356
# Epoch 369/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4253 - accuracy: 0.8539
# Epoch 370/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4349 - accuracy: 0.8402
# Epoch 371/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4724 - accuracy: 0.8356
# Epoch 372/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4939 - accuracy: 0.8219
# Epoch 373/600
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3656 - accuracy: 0.8630
# Epoch 374/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5333 - accuracy: 0.7717
# Epoch 375/600
# 7/7 [==============================] - 0s 50ms/step - loss: 0.4751 - accuracy: 0.8493
# Epoch 376/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4184 - accuracy: 0.8402
# Epoch 377/600
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3978 - accuracy: 0.8584
# Epoch 378/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4047 - accuracy: 0.8447
# Epoch 379/600
# 7/7 [==============================] - 0s 51ms/step - loss: 0.3595 - accuracy: 0.8858
# Epoch 380/600
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4234 - accuracy: 0.8539
# Epoch 381/600
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3859 - accuracy: 0.8813
# Epoch 382/600
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4653 - accuracy: 0.8219
# Epoch 383/600
# ...
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2279 - accuracy: 0.9198
# Epoch 443/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1923 - accuracy: 0.9494
# Epoch 444/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2943 - accuracy: 0.8903
# Epoch 445/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1949 - accuracy: 0.9409
# Epoch 446/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2037 - accuracy: 0.9409
# Epoch 447/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2655 - accuracy: 0.8987
# Epoch 448/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2293 - accuracy: 0.9367
# Epoch 449/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2573 - accuracy: 0.8987
# Epoch 450/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2485 - accuracy: 0.9156
# Epoch 451/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2398 - accuracy: 0.9114
# Epoch 452/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2253 - accuracy: 0.9241
# Epoch 453/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2380 - accuracy: 0.9241
# Epoch 454/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2295 - accuracy: 0.9156
# Epoch 455/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2560 - accuracy: 0.9072
# Epoch 456/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2038 - accuracy: 0.9367
# Epoch 457/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2228 - accuracy: 0.9198
# Epoch 458/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2121 - accuracy: 0.9241
# Epoch 459/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3046 - accuracy: 0.8903
# Epoch 460/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2167 - accuracy: 0.9072
# Epoch 461/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1642 - accuracy: 0.9536
# Epoch 462/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2451 - accuracy: 0.8945
# Epoch 463/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2290 - accuracy: 0.9241
# Epoch 464/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1693 - accuracy: 0.9325
# Epoch 465/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1649 - accuracy: 0.9451
# Epoch 466/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2346 - accuracy: 0.9241
# Epoch 467/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2309 - accuracy: 0.9409
# Epoch 468/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2286 - accuracy: 0.9156
# Epoch 469/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2288 - accuracy: 0.9283
# Epoch 470/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2558 - accuracy: 0.9114
# Epoch 471/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1694 - accuracy: 0.9283
# Epoch 472/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1905 - accuracy: 0.9451
# Epoch 473/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2292 - accuracy: 0.9283
# Epoch 474/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1944 - accuracy: 0.9198
# Epoch 475/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2455 - accuracy: 0.9283
# Epoch 476/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2336 - accuracy: 0.9114
# Epoch 477/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2476 - accuracy: 0.9156
# Epoch 478/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2663 - accuracy: 0.9283
# Epoch 479/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2615 - accuracy: 0.8987
# Epoch 480/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1998 - accuracy: 0.9367
# Epoch 481/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1688 - accuracy: 0.9367
# Epoch 482/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2450 - accuracy: 0.9114
# Epoch 483/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2185 - accuracy: 0.9156
# Epoch 484/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2231 - accuracy: 0.9198
# Epoch 485/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2324 - accuracy: 0.9283
# Epoch 486/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2160 - accuracy: 0.9198
# Epoch 487/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2603 - accuracy: 0.8945
# Epoch 488/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2598 - accuracy: 0.9198
# Epoch 489/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2806 - accuracy: 0.9114
# Epoch 490/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2215 - accuracy: 0.9156
# Epoch 491/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2194 - accuracy: 0.9072
# Epoch 492/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2235 - accuracy: 0.9156
# Epoch 493/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2367 - accuracy: 0.9072
# Epoch 494/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2726 - accuracy: 0.9072
# Epoch 495/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2257 - accuracy: 0.9156
# Epoch 496/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2118 - accuracy: 0.9325
# Epoch 497/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2111 - accuracy: 0.9114
# Epoch 498/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2509 - accuracy: 0.9198
# Epoch 499/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2076 - accuracy: 0.9325
# Epoch 500/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2428 - accuracy: 0.8945
# Epoch 501/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1500 - accuracy: 0.9241
# Epoch 502/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1950 - accuracy: 0.9198
# Epoch 503/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2231 - accuracy: 0.9030
# Epoch 504/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2181 - accuracy: 0.9156
# Epoch 505/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1794 - accuracy: 0.9409
# Epoch 506/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1552 - accuracy: 0.9367
# Epoch 507/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2288 - accuracy: 0.9156
# Epoch 508/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1891 - accuracy: 0.9536
# Epoch 509/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1888 - accuracy: 0.9325
# Epoch 510/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2173 - accuracy: 0.9325
# Epoch 511/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1811 - accuracy: 0.9325
# Epoch 512/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2219 - accuracy: 0.9283
# Epoch 513/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2005 - accuracy: 0.9241
# Epoch 514/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2042 - accuracy: 0.9367
# Epoch 515/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1834 - accuracy: 0.9451
# Epoch 516/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2416 - accuracy: 0.9156
# Epoch 517/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2082 - accuracy: 0.9283
# Epoch 518/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2175 - accuracy: 0.9156
# Epoch 519/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2205 - accuracy: 0.9241
# Epoch 520/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2241 - accuracy: 0.9198
# Epoch 521/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2183 - accuracy: 0.9156
# Epoch 522/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2169 - accuracy: 0.9114
# Epoch 523/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2531 - accuracy: 0.9198
# Epoch 524/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1905 - accuracy: 0.9156
# Epoch 525/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2432 - accuracy: 0.9030
# Epoch 526/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2372 - accuracy: 0.9114
# Epoch 527/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1608 - accuracy: 0.9451
# Epoch 528/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1511 - accuracy: 0.9494
# Epoch 529/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1933 - accuracy: 0.9409
# Epoch 530/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1587 - accuracy: 0.9451
# Epoch 531/600
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1753 - accuracy: 0.9451
# Epoch 532/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1782 - accuracy: 0.9409
# Epoch 533/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1851 - accuracy: 0.9283
# Epoch 534/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1964 - accuracy: 0.9198
# Epoch 535/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1862 - accuracy: 0.9451
# Epoch 536/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1635 - accuracy: 0.9367
# Epoch 537/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2110 - accuracy: 0.9072
# Epoch 538/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2156 - accuracy: 0.9114
# Epoch 539/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3377 - accuracy: 0.8945
# Epoch 540/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1569 - accuracy: 0.9409
# Epoch 541/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1893 - accuracy: 0.9409
# Epoch 542/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1707 - accuracy: 0.9409
# Epoch 543/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2286 - accuracy: 0.9156
# Epoch 544/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2423 - accuracy: 0.9156
# Epoch 545/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2078 - accuracy: 0.9241
# Epoch 546/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1428 - accuracy: 0.9494
# Epoch 547/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2224 - accuracy: 0.9072
# Epoch 548/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2347 - accuracy: 0.9241
# Epoch 549/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2078 - accuracy: 0.9241
# Epoch 550/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2332 - accuracy: 0.8945
# Epoch 551/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2558 - accuracy: 0.8903
# Epoch 552/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1844 - accuracy: 0.9198
# Epoch 553/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1547 - accuracy: 0.9409
# Epoch 554/600
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1876 - accuracy: 0.9283
# Epoch 555/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2088 - accuracy: 0.9241
# Epoch 556/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1618 - accuracy: 0.9409
# Epoch 557/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1679 - accuracy: 0.9325
# Epoch 558/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2259 - accuracy: 0.9409
# Epoch 559/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2101 - accuracy: 0.9325
# Epoch 560/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1270 - accuracy: 0.9536
# Epoch 561/600
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1816 - accuracy: 0.9494
# Epoch 562/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2207 - accuracy: 0.9283
# Epoch 563/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1656 - accuracy: 0.9451
# Epoch 564/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2089 - accuracy: 0.9409
# Epoch 565/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1938 - accuracy: 0.9325
# Epoch 566/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2084 - accuracy: 0.9198
# Epoch 567/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1588 - accuracy: 0.9367
# Epoch 568/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1291 - accuracy: 0.9705
# Epoch 569/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1370 - accuracy: 0.9662
# Epoch 570/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1358 - accuracy: 0.9578
# Epoch 571/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1712 - accuracy: 0.9367
# Epoch 572/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1643 - accuracy: 0.9578
# Epoch 573/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1716 - accuracy: 0.9283
# Epoch 574/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1706 - accuracy: 0.9325
# Epoch 575/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1779 - accuracy: 0.9451
# Epoch 576/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1716 - accuracy: 0.9451
# Epoch 577/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1529 - accuracy: 0.9494
# Epoch 578/600
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1544 - accuracy: 0.9494
# Epoch 579/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1773 - accuracy: 0.9409
# Epoch 580/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1168 - accuracy: 0.9620
# Epoch 581/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1445 - accuracy: 0.9494
# Epoch 582/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1560 - accuracy: 0.9494
# Epoch 583/600
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1519 - accuracy: 0.9578
# Epoch 584/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1712 - accuracy: 0.9578
# Epoch 585/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2030 - accuracy: 0.9367
# Epoch 586/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2024 - accuracy: 0.9325
# Epoch 587/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2191 - accuracy: 0.9451
# Epoch 588/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1457 - accuracy: 0.9536
# Epoch 589/600
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1858 - accuracy: 0.9451
# Epoch 590/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1744 - accuracy: 0.9241
# Epoch 591/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1504 - accuracy: 0.9494
# Epoch 592/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1274 - accuracy: 0.9578
# Epoch 593/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1538 - accuracy: 0.9494
# Epoch 594/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1747 - accuracy: 0.9241
# Epoch 595/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1580 - accuracy: 0.9578
# Epoch 596/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1748 - accuracy: 0.9536
# Epoch 597/600
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2156 - accuracy: 0.9241
# Epoch 598/600
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2032 - accuracy: 0.9283
# Epoch 599/600
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2041 - accuracy: 0.9367
# Epoch 600/600
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1738 - accuracy: 0.9325
# 9/9 [==============================] - 1s 19ms/step - loss: 1.5418 - accuracy: 0.5606
# Accuracy: 56.06%

# %%
Accuracy = accuracy
avg_acc = np.average(Accuracy)
Accuracy, avg_acc
# Out:
# (array([69.75088716, 48.40989411, 82.41758347, 50.        , 57.97101259,
#         46.97674513, 66.06498361, 71.21770978, 56.06060624]),
#  60.98549134201474)

# %%
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 1, 22, 1875  0           []
#                                 )]
#
#  permute_8 (Permute)            (None, 1875, 22, 1)  0           ['input_9[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 1875, 22, 8)  256         ['permute_8[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 1875, 22, 8)  32         ['conv2d_8[0][0]']
#  ormalization)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 1875, 1, 16)  352        ['batch_normalization_56[0][0]']
#  onv2D)
#
#  batch_normalization_57 (BatchN  (None, 1875, 1, 16)  64         ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 1875, 1, 16)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 187, 1, 16)  0           ['activation_64[0][0]']
#  ooling2D)
#
#  dropout_48 (Dropout)           (None, 187, 1, 16)   0           ['average_pooling2d_16[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 187, 1, 16)  512         ['dropout_48[0][0]']
#  onv2D)
#
#  batch_normalization_58 (BatchN  (None, 187, 1, 16)  64          ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 187, 1, 16)   0           ['batch_normalization_58[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 18, 1, 16)   0           ['activation_65[0][0]']
#  ooling2D)
#
#  dropout_49 (Dropout)           (None, 18, 1, 16)    0           ['average_pooling2d_17[0][0]']
#
#  tf.compat.v1.squeeze_8 (TFOpLa  (None, 18, 16)      0           ['dropout_49[0][0]']
#  mbda)
#
#  conv1d_40 (Conv1D)             (None, 18, 12)       780         ['tf.compat.v1.squeeze_8[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 18, 12)      48          ['conv1d_40[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 18, 12)       0           ['batch_normalization_59[0][0]']
#
#  dropout_50 (Dropout)           (None, 18, 12)       0           ['activation_66[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 18, 12)       588         ['dropout_50[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 18, 12)      48          ['conv1d_41[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 18, 12)       0           ['batch_normalization_60[0][0]']
#
#  dropout_51 (Dropout)           (None, 18, 12)       0           ['activation_67[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 18, 12)       204         ['tf.compat.v1.squeeze_8[0][0]']
#
#  add_16 (Add)                   (None, 18, 12)       0           ['dropout_51[0][0]',
#                                                                   'conv1d_42[0][0]']
#
#  activation_68 (Activation)     (None, 18, 12)       0           ['add_16[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 18, 12)       588         ['activation_68[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 18, 12)      48          ['conv1d_43[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 18, 12)       0           ['batch_normalization_61[0][0]']
#
#  dropout_52 (Dropout)           (None, 18, 12)       0           ['activation_69[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 18, 12)       588         ['dropout_52[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 18, 12)      48          ['conv1d_44[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 18, 12)       0           ['batch_normalization_62[0][0]']
#
#  dropout_53 (Dropout)           (None, 18, 12)       0           ['activation_70[0][0]']
#
#  add_17 (Add)                   (None, 18, 12)       0           ['dropout_53[0][0]',
#                                                                   'activation_68[0][0]']
#
#  activation_71 (Activation)     (None, 18, 12)       0           ['add_17[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  (None, 12)          0           ['activation_71[0][0]']
#  icingOpLambda)
#
#  dense_8 (Dense)                (None, 4)            52          ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 4,272
# Trainable params: 4,096
# Non-trainable params: 176
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Evaluation

# %%
# Evaluation function from Problem 2 Homework 4
def evaluate_model(history,X_test,y_test,model):
    scores = model.evaluate((X_test),y_test, verbose=1)
    print("Accuracy: %.2f%%" % (scores[1]*100))
    
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model - Accuracy')
    plt.show()
    
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model- Loss')
    plt.plot(history.history['loss'])
    plt.show()

# %%
evaluate_model(history,X_test,y_test_ohe,model)
# Out:
# 9/9 [==============================] - 0s 16ms/step - loss: 1.5418 - accuracy: 0.5606
# Accuracy: 56.06%

# %%
# Convert prediction matrix into array of indices for the most probable class
y_pred = np.argmax(model.predict(X_test), axis = 1)
y_test = np.argmax(y_test_ohe, axis = 1) 

# Confusion matrix for each model
EEGTCNet_confusion = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
labels = ['1', '2', '3', '4']
fig = plt.figure(figsize=(15,10))
axes = fig.add_subplot(1,1,1)
sns.heatmap(EEGTCNet_confusion, annot=True, cmap='Blues', fmt = "d", xticklabels = labels, yticklabels = labels)
axes.set_title('EEGTCNet Model Confusion Matrix of Subject 9')
axes.set_xlabel('Predicted Value')
axes.set_ylabel('True Value')

EEGTCNet_accuracy = accuracy_score(y_test, y_pred)
EEGTCNet_precision = precision_score(y_test, y_pred, average='macro')

print("EEGTCNet Model Accuracy of Subject 9: {accuracy:.5f} |".format(accuracy=EEGTCNet_accuracy),
      "EEGTCNet Model Precision of Subject 9: {precision:.5f}\n".format(precision=EEGTCNet_precision))
# Out:
# EEGTCNet Model Accuracy of Subject 9: 0.56061 | EEGTCNet Model Precision of Subject 9: 0.54951

# %% [markdown]
# # Multi-Layer CNN Model

# %% [markdown]
# ##Model

# %% [markdown]
# ![cnn_architecture.png](data:image/png;base64,...)

# %%
# CNN model with an adjustable number of convolution blocks. Scripted in PyTorch

class CNN(nn.Module):
  def __init__(self, input_size,filter_size,num_blocks):
    super(CNN,self).__init__()
    # num_blocks = Number of additional convolution blocks to be added
    self.num_blocks = num_blocks
    # 2D convolution across time samples
    self.conv_temporal = nn.Conv2d(1,50,(1,filter_size),stride=1,bias=False,
                                   padding=1)
    # 2D convolution: spatial filtering with weights for all possible pairs of 
    # electrodes with filters of the preceding temporal convolution
    self.conv_spatial = nn.Conv2d(50,50,(input_size,1),stride=(1, 1),bias=False,
                                  padding=1)
    # Batch normalization
    self.bnorm = nn.BatchNorm2d(50,momentum=0.1,affine=True,eps=1e-5)
    # ELU activation function
    self.elu = nn.ELU()
    # Max pooling
    self.pool = nn.MaxPool2d(kernel_size=(1,3), stride=(1,3))

    # Add a convolution block to the network. The block consists of a dropout
    # layer, 2D convolution, batch normalization, ELU activation function, and a
    # max pooling layer
    self.md = nn.ModuleDict({})
    def add_conv_pool_block(self,n_filters_in,n_filters_out,block_num):
      num = block_num
      self.md["drop{:d}".format(num)] = nn.Dropout(0.5)
      self.md["conv{:d}".format(num)] = nn.Conv2d(n_filters_in,n_filters_out,(1,10),
                            stride=(1, 1), bias=False,padding=1)
      self.md["bnorm{:d}".format(num)] = nn.BatchNorm2d(n_filters_out,momentum=0.1,
                               affine=True,eps=1e-5)
      self.md["elu{:d}".format(num)] = nn.ELU()
      self.md["pool{:d}".format(num)] = nn.MaxPool2d(
                  kernel_size=(1,3), stride=(1,3))
      
      
    # Add x conv/pool blocks where x = num_blocks (x can be up to 3)
    n_filters_in = 50
    n_filters_out = 100
    for i in range(self.num_blocks):
      if (i+1) == 3:
        n_filters_out = 200
      add_conv_pool_block(self, n_filters_in, n_filters_out,i)
      n_filters_in = n_filters_out

    inp = 616
    if self.num_blocks == 0:
      inp = 616
    elif self.num_blocks == 1:
      inp = 203
    elif self.num_blocks == 2:
      inp = 65
    elif self.num_blocks == 3:
      inp = 19    
    # Dropout layer 
    self.drop_last = nn.Dropout(0.5)
    # Linear layer and classifier
    self.dense = nn.Linear(inp,512)
    self.classifier = nn.Linear(512,4)
    
    self.init_weights()
    
    
  def init_weights(self):
    init.xavier_uniform_(self.conv_temporal.weight, gain=1)
    init.xavier_uniform_(self.conv_spatial.weight, gain=1)
    init.constant_(self.bnorm.weight, 1)
    init.constant_(self.bnorm.bias, 0)

    for i in range(self.num_blocks):
      init.xavier_uniform_(self.md["conv{:d}".format(i)].weight, gain=1)
      init.constant_(self.md["bnorm{:d}".format(i)].weight, 1)
      init.constant_(self.md["bnorm{:d}".format(i)].bias, 0)
    
    init.xavier_uniform_(self.dense.weight, gain=1)
    init.xavier_uniform_(self.classifier.weight, gain=1)
    init.constant_(self.classifier.bias, 0)

  def forward(self,x):
    x = self.conv_temporal(x)
    x = self.conv_spatial(x)
    x = self.bnorm(x)
    x = self.elu(x)
    x = self.pool(x)

    for i in range(self.num_blocks):
      dropx = self.md["drop{:d}".format(i)]
      x = dropx(x)
      convx = self.md["conv{:d}".format(i)]
      x = convx(x)
      bnormx = self.md["bnorm{:d}".format(i)]
      x = bnormx(x)
      elux = self.md["elu{:d}".format(i)]
      x = elux(x)
      poolx = self.md["pool{:d}".format(i)]
      x = poolx(x)

    x = self.drop_last(x)
    x = torch.mean(x, x.ndimension()-2)
    x = torch.mean(x, x.ndimension()-2)

    x = self.dense(x)
    x = self.classifier(x)
    
    return x

# %%
class MLP(nn.Module):
  # Multi-layer perceptron with 2 hidden layers and dropout = 0.5
  def __init__(self):
    super(MLP,self).__init__()
    self.h1 = nn.Linear(16, 50)
    self.drop1 = nn.Dropout(0.5)
    self.elu = nn.ELU()
    self.h2 = nn.Linear(50, 4)
    self.drop2 = nn.Dropout(0.5)
    self.softmax = nn.LogSoftmax(dim=1)

    self.layers = nn.Sequential(
        self.h1,self.drop1,self.elu,self.h2,self.drop2,self.softmax)
    self.init_weights()

  def init_weights(self):
      init.xavier_uniform_(self.h1.weight)
      init.xavier_uniform_(self.h2.weight)

  def forward(self, x):
    return self.layers(x)

# %%
class MCNN(nn.Module):
  def __init__(self,input_size,filter_size1,filter_size2,
               filter_size3,filter_size4):
    super(MCNN,self).__init__()
    # MCNN concatenates features of CNN's 1-4 as input to a MLP
    # with 2 hidden layers. MLP classifies MI state from these combined outputs
    self.cnn1 = CNN(input_size,filter_size=filter_size1,num_blocks=0)
    self.cnn2 = CNN(input_size,filter_size=filter_size2,num_blocks=1)
    self.cnn3 = CNN(input_size,filter_size=filter_size3,num_blocks=2)
    self.cnn4 = CNN(input_size,filter_size=filter_size4,num_blocks=3)
    self.mlp = MLP()
  
  def forward(self,input1,input2,input3,input4):
    c1 = self.cnn1(input1)
    c2 = self.cnn2(input2)
    c3 = self.cnn3(input3)
    c4 = self.cnn4(input4)
    combined = torch.cat((c1,c2,c3,c4), dim=1)
    out = self.mlp(combined)

    return out

# %% [markdown]
# ## Training and Evaluation

# %%
# Parameters for MCNN
input_size = 22
filter_size1 = 30
filter_size2 = 25
filter_size3 = 20
filter_size4 = 10
batch_size = 16

# %%
def MCNNevaluate(model, X, Y):
    model.eval()
    with torch.no_grad():
      results = []
      batch_size = 5
      accuracy = []
      predicted = []
      lab = []
    
      for i in range(int(len(X)/batch_size-1)):
          s = i*batch_size
          e = i*batch_size+batch_size

          inputs = Variable(torch.from_numpy(X[s:e]).to(device))
          labels = Variable(torch.LongTensor(np.array([Y[s:e]])).to(device))
          labels = torch.sub(labels,1)
          labels = torch.squeeze(labels)
          pred = model(inputs,inputs,inputs,inputs)
          predicted = torch.argmax(pred.data,1)
          correct = (predicted == labels).float()
          acc = correct.sum() / len(correct)
          acc = torch.round(acc * 100)
          accuracy.append(acc.cpu().numpy())

      meanacc = np.mean(np.asarray(accuracy))

      return meanacc
    model.train()

# %%
def train(model):
  if torch.cuda.is_available():
    model.to(device)
    criterion = nn.NLLLoss().to(device)
  optimizer = optim.Adam(model.parameters(),lr=1e-4, weight_decay=0.01)

  for epoch in range(100):  # loop over the dataset multiple times
      print("\nEpoch ", epoch)
      
      running_loss = 0.0
      for i in range(int(len(X_train)/batch_size-1)):
          # zero the parameter gradients
          optimizer.zero_grad()
          s = i*batch_size
          e = i*batch_size+batch_size
          
          inputs = torch.from_numpy(X_train[s:e])
          labels = torch.LongTensor(np.array([Y_train[s:e]]))
          labels = torch.sub(labels,1)

          # wrap them in Variable
          inputs, labels = Variable(inputs), Variable(labels)
          inputs, labels = inputs.to(device), labels.to(device)

          

          # forward + backward + optimize
          outputs = model(inputs,inputs,inputs,inputs) 

          loss = criterion(outputs,
                          torch.squeeze(labels))
          loss.backward()
          
          
          optimizer.step()
          
          running_loss += float(loss.item())

      print("Training Loss ", running_loss)
      acc = MCNNevaluate(model, X_train, Y_train)
      print('Accuracy:',acc)

# %%
torch.cuda.empty_cache()
if torch.cuda.is_available():
  torch.cuda.set_device(0)
  device = torch.device('cuda')

accuracy = np.zeros(9)

for subject in range(1, 10): # Obtain performance metrics for all 9 subjects
  print('Subject', subject)
  [X_train, y_train_ohe, X_test, y_test_ohe, Y_train, Y_test] = Subject_data_label(subject, data_path) 
  X_train = X_train.astype(np.float32)
  X_test = X_test.astype(np.float32)

  # Training
  model = MCNN(input_size,filter_size1,filter_size2,filter_size3,filter_size4)
  train(model)

  # Testing
  scores = MCNNevaluate(model,X_test,Y_test)
  accuracy[subject-1] = scores

# %%
accuracy

# %% [markdown]
# ## Loss and Accuracy

# %%
def train_loss_and_accuracy(model):
  if torch.cuda.is_available():
    model.to(device)
    criterion = nn.NLLLoss().to(device)
  optimizer = optim.Adam(model.parameters(),lr=1e-4, weight_decay=0.01)
  loss_values = []
  acc_values = []
  for epoch in range(100):  # loop over the dataset multiple times
      print("\nEpoch ", epoch)
      
      running_loss = 0.0
      for i in range(int(len(X_train)/batch_size-1)):
          # zero the parameter gradients
          optimizer.zero_grad()
          s = i*batch_size
          e = i*batch_size+batch_size
          
          inputs = torch.from_numpy(X_train[s:e])
          labels = torch.LongTensor(np.array([Y_train[s:e]]))
          labels = torch.sub(labels,1)

          # wrap them in Variable
          inputs, labels = Variable(inputs), Variable(labels)
          inputs, labels = inputs.to(device), labels.to(device)

          

          # forward + backward + optimize
          outputs = model(inputs,inputs,inputs,inputs) 

          loss = criterion(outputs,
                          torch.squeeze(labels))
          loss.backward()
          
          
          optimizer.step()
          
          running_loss += float(loss.item())

      loss_values.append(running_loss/len(X_train))
      acc = MCNNevaluate(model, X_train, Y_train)
      acc_values.append(acc)
  return loss_values, acc_values

# %%
train_loss, train_acc = train_loss_and_accuracy(model)
fig1, ax_acc = plt.subplots()
plt.plot(train_acc)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('MCNN Model - Accuracy')
plt.show()
    
fig2, ax_loss = plt.subplots()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('MCNN Model - Loss')
plt.plot(train_loss)
plt.show()
